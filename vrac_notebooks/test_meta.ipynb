# %%
import sys
sys.path.insert(0, '../python_scripts')
import importlib
import h_gen
import meta
importlib.reload(h_gen)
importlib.reload(meta)
# Out:
# <module 'meta' from '../python_scripts\\meta.py'>

# %%
meta.generate_cluster_from_imgs('../train/train')
# Out:
# IT WILL SAVE DATA IN : data_clusters.p,cluster_0.p,cluster_1.p
# 3777 3777

# %%
meta.get_cluster_data('cluster_0.p')
# Out:
# defaultdict(int,
#             {'ALB': ['img_01117.jpg',
#               'img_06215.jpg',
#               'img_01262.jpg',
#               'img_01540.jpg',
#               'img_05886.jpg',
#               'img_06758.jpg',
#               'img_05550.jpg',
#               'img_05583.jpg',
#               'img_07040.jpg',
#               'img_06313.jpg',
#               'img_00810.jpg',
#               'img_07252.jpg',
#               'img_04187.jpg',
#               'img_00396.jpg',
#               'img_07726.jpg',
#               'img_00881.jpg',
#               'img_05511.jpg',
#               'img_03357.jpg',
#               'img_04588.jpg',
#               'img_07039.jpg',
#               'img_04361.jpg',
#               'img_04635.jpg',
#               'img_02583.jpg',
#               'img_00012.jpg',
#               'img_00085.jpg',
#               'img_07170.jpg',
#               'img_06503.jpg',
#               'img_02635.jpg',
#               'img_03171.jpg',
# ...

# %%
meta.get_cluster_data('cluster_1.p')
